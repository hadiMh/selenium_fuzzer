# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
from collect_page_urls import find_all_urls_of_single_webpage

# %%
# all_urls = find_all_urls_of_single_webpage('google.com', driver)

# %%
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

caps = DesiredCapabilities().CHROME

caps["pageLoadStrategy"] = "eager" 

driver = webdriver.Chrome(desired_capabilities=caps)

# %%
all_explored_urls = []
# all_urls = find_all_urls_of_single_webpage('python.org', driver)
all_urls = ['https://ravaghschool.ir']

# %%
while len(all_urls) != 0:
    print('-' * 20)
    print(f'All urls list length: {len(all_urls)}')

    popped_url = all_urls[0] #all_urls.pop(0)
    print(f'Url: {popped_url}\n')

    if popped_url not in all_explored_urls:
        # add this url to explored urls list so we know it is already explored.
        all_explored_urls.append(popped_url)
        print(f'Eploring url: {popped_url}')

        popped_url = popped_url.replace('www.','').replace('https://', '').replace('http://', '')

        urls_of_this_page = find_all_urls_of_single_webpage(popped_url, driver)
        print(f'Found {len(urls_of_this_page)} urls on this page.')

        new_found_urls = list(set(urls_of_this_page).difference(set(all_urls+all_explored_urls)))
        print(f'{len(new_found_urls)} urls are new.')

        all_urls.extend(new_found_urls)
        print(f'Added {len(new_found_urls)} new urls to all urls list. all urls list new length is: {len(all_urls)}')
    else:
        print('This url is already explored.')

    all_urls.pop(0)
# Out:
# %ab%d8%a7%d9%82-%d8%a8%d8%a7-%d8%b4%d9%87%d8%af%d8%a7/
# ['http://www.ravaghschool.ir/%d9%85%db%8c%d8%ab%d8%a7%d9%82-%d8%a8%d8%a7-%d8%b4%d9%87%d8%af%d8%a7/']
# There are 28 <a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 33
# --------------------
# All urls list length: 32
# Url: https://ravaghschool.ir/%d8%b4%d8%a8%db%8c-%d8%a8%d8%a7-%d8%b3%d8%b1%d8%af%d8%a7%d8%b1-%d8%af%d9%84%d9%87%d8%a7/
#
# Eploring url: https://ravaghschool.ir/%d8%b4%d8%a8%db%8c-%d8%a8%d8%a7-%d8%b3%d8%b1%d8%af%d8%a7%d8%b1-%d8%af%d9%84%d9%87%d8%a7/
# ['http://www.ravaghschool.ir/%d8%b4%d8%a8%db%8c-%d8%a8%d8%a7-%d8%b3%d8%b1%d8%af%d8%a7%d8%b1-%d8%af%d9%84%d9%87%d8%a7/']
# There are 54 <a> tags on this page.
# 5 urls are Inside urls.
# 3 where duplicate
# 1 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 32
# --------------------
# All urls list length: 31
# Url: https://ravaghschool.ir/%d9%85%d8%ae%d8%a7%d8%b7%d8%a8%d8%a7%d9%86-%d8%b1%d9%88%d8%a7%d9%82/
#
# Eploring url: https://ravaghschool.ir/%d9%85%d8%ae%d8%a7%d8%b7%d8%a8%d8%a7%d9%86-%d8%b1%d9%88%d8%a7%d9%82/
# ['http://www.ravaghschool.ir/%d9%85%d8%ae%d8%a7%d8%b7%d8%a8%d8%a7%d9%86-%d8%b1%d9%88%d8%a7%d9%82/']
# There are 28 <a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 31
# --------------------
# All urls list length: 30
# Url: https://ravaghschool.ir/cls92/
#
# Eploring url: https://ravaghschool.ir/cls92/
# ['http://www.ravaghschool.ir/cls92/']
# There are 53 <a> tags on this page.
# 4 urls are Inside urls.
# 2 where duplicate
# 1 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is:
<a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 1 urls are new.
# Added 1 new urls to all urls list. all urls list new length is: 17
# --------------------
# All urls list length: 16
# Url: https://ravaghschool.ir/cls91/
#
# Eploring url: https://ravaghschool.ir/cls91/
# ['http://www.ravaghschool.ir/cls91/']
# There are 59 <a> tags on this page.
# 4 urls are Inside urls.
# 2 where duplicate
# 1 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 16
# --------------------
# All urls list length: 15
# Url: https://ravaghschool.ir/cls8/
#
# Eploring url: https://ravaghschool.ir/cls8/
# ['http://www.ravaghschool.ir/cls8/']
# There are 69 <a> tags on this page.
# 4 urls are Inside urls.
# 2 where duplicate
# 1 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 15
# --------------------
# All urls list length: 14
# Url: https://ravaghschool.ir/kadr/
#
# Eploring url: https://ravaghschool.ir/kadr/
# ['http://www.ravaghschool.ir/kadr/']
# There are 58 <a> tags on this page.
# 34 urls are Inside urls.
# 32 where duplicate
# 1 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 14
# --------------------
# All urls list length: 13
# Url: https://ravaghschool.ir/%d9%88%db%8c%da%98%d9%87-%d8%a8%d8%b1%d9%86%d8%a7%d9%85%d9%87-%d9%87%d8%a7%db%8c-%d8%af%d9%87%d9%87-%d9%81%d8%ac%d8%b1/
#
# Eploring url: https://ravaghschool.ir/%d9%88%db%8c%da%98%d9%87-%d8%a8%d8%b1%d9%86%d8%a7%d9%85%d9%87-%d9%87%d8%a7%db%8c-%d8%af%d9%87%d9%87-%d9%81%d8%ac%d8%b1/
# ['http://www.ravaghschool.ir/%d9%88%db%8c%da%98%d9%87-%d8%a8%d8%b1%d9%86%d8%a7%d9%85%d9%87-%d9%87%d8%a7%db%8c-%d8%af%d9%87%d9%87-%d9%81%d8%ac%d8%b1/']
# There are 35 <a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 13
# --------------------
# All urls list length: 12
# Url: https://ravaghschool.ir/%d8%ac%d9%84%d8%b3%d9%87-%d8%aa%d9%88%d8%ac%db%8c%d9%87%db%8c-%d8%ae%d8%a7%d9%86%d9%88%d8%a7%d8%af%d9%87-%d9%87%d8%a7/
#
# Eploring url: https://ravaghschool.ir/%d8%ac%d9%84%d8%b3%d9%87-%d8%aa%d9%88%d8%ac%db%8c%d9%87%db%8c-%d8%ae%d8%a7%d9%86%d9%88%d8%a7%d8%af%d9%87-%d9%87%d8%a7/
# ['http://www.ravaghschool.ir/%d8%ac%d9%84%d8%b3%d9%87-%d8%aa%d9%88%d8%ac%db%8c%d9%87%db%8c-%d8%ae%d8%a7%d9%86%d9%88%d8%a7%d8%af%d9%87-%d9%87%d8%a7/']
# There are 28 <a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 12
# --------------------
# All urls list length: 11
# Url: https://ravaghschool.ir/%d8%b1%d8%b2%d9%85%d8%a7%db%8c%d8%b4-%d8%ac%d8%a7%db%8c-%d9%be%d8%a7%db%8c-%d8%a7%d9%85%db%8c%d8%b1/
#
# Eploring url: https://ravaghschool.ir/%d8%b1%d8%b2%d9%85%d8%a7%db%8c%d8%b4-%d8%ac%d8%a7%db%8c-%d9%be%d8%a7%db%8c-%d8%a7%d9%85%db%8c%d8%b1/
# ['http://www.ravaghschool.ir/%d8%b1%d8%b2%d9%85%d8%a7%db%8c%d8%b4-%d8%ac%d8%a7%db%8c-%d9%be%d8%a7%db%8c-%d8%a7%d9%85%db%8c%d8%b1/']
# There are 47 <a> tags on this page.
# 5 urls are Inside urls.
# 3 where duplicate
# 1 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is:
<a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 7
# --------------------
# All urls list length: 6
# Url: https://ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/page/2/
#
# Eploring url: https://ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/page/2/
# ['http://www.ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/page/2/']
# There are 109 <a> tags on this page.
# 13 urls are Inside urls.
# 12 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 6
# --------------------
# All urls list length: 5
# Url: https://ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/page/3/
#
# Eploring url: https://ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/page/3/
# ['http://www.ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/page/3/']
# There are 60 <a> tags on this page.
# 5 urls are Inside urls.
# 4 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 5
# --------------------
# All urls list length: 4
# Url: https://ravaghschool.ir/blog/page/4/
#
# Eploring url: https://ravaghschool.ir/blog/page/4/
# ['http://www.ravaghschool.ir/blog/page/4/']
# There are 96 <a> tags on this page.
# 7 urls are Inside urls.
# 4 where duplicate
# 2 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 4
# --------------------
# All urls list length: 3
# Url: https://ravaghschool.ir/blog/page/2/
#
# Eploring url: https://ravaghschool.ir/blog/page/2/
# ['http://www.ravaghschool.ir/blog/page/2/']
# There are 105 <a> tags on this page.
# 7 urls are Inside urls.
# 4 where duplicate
# 2 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 3
# --------------------
# All urls list length: 2
# Url: https://ravaghschool.ir/blog/page/3/
#
# Eploring url: https://ravaghschool.ir/blog/page/3/
# ['http://www.ravaghschool.ir/blog/page/3/']
# There are 105 <a> tags on this page.
# 7 urls are Inside urls.
# 4 where duplicate
# 2 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 2
# --------------------
# All urls list length: 1
# Url: https://ravaghschool.ir/sabtenam/
#
# Eploring url: https://ravaghschool.ir/sabtenam/
# ['http://www.ravaghschool.ir/sabtenam/']
# There are 22 <a> tags on this page.
# 3 urls are Inside urls.
# 2 where duplicate
# 0 has # and are duplicates.
# Final result: total pure links = 1
# Found 1 urls on this page.
# 0 urls are new.
# Added 0 new urls to all urls list. all urls list new length is: 1

# %%
all_explored_urls
# Out:
# ['https://ravaghschool.ir',
#  'https://ravaghschool.ir/%d9%87%db%8c%d8%a6%d8%aa-%d9%87%d9%81%d8%aa%da%af%db%8c-%d8%b1%d9%88%d8%a7%d9%82/',
#  'https://ravaghschool.ir/category/%d8%aa%d8%b1%d8%a8%db%8c%d8%aa-%d9%88-%d8%a2%d9%85%d9%88%d8%b2%d8%b4/',
#  'https://ravaghschool.ir/blog/',
#  'https://ravaghschool.ir/%da%a9%d9%84%d8%a7%d8%b3-%d9%87%d8%a7%db%8c-%d8%aa%d8%b3%d8%aa-%d9%88-%d9%86%da%a9%d8%aa%d9%87-%d9%be%d8%a7%db%8c%d9%87-%d9%86%d9%87%d9%85/',
